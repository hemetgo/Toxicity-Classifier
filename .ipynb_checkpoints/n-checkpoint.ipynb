# %% [markdown]
# # Get Data

# %%
from tensorflow.keras.preprocessing.text import Tokenizer
from tensorflow.keras.preprocessing.sequence import pad_sequences
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, Flatten, Embedding, Dropout
from tensorflow.keras.layers import Conv1D, MaxPooling1D, GlobalMaxPooling1D, MaxPool1D

# %%
import numpy as np
import pandas as pd
import re
from sklearn.model_selection import train_test_split

# %%
df = pd.read_csv('data.csv')
df.head()
# Out:
#    Unnamed: 0  Toxicity                                              tweet
# 0           0         0   @user when a father is dysfunctional and is s...
# 1           1         0  @user @user thanks for #lyft credit i can't us...
# 2           2         0                                bihday your majesty
# 3           3         0  #model   i love u take with u all the time in ...
# 4           4         0             factsguide: society now    #motivation

# %%
df['Toxicity'].value_counts()
# Out:
# 0    32592
# 1    24153
# Name: Toxicity, dtype: int64

# %%
vc = df['Toxicity'].value_counts()
index = list(vc.index)
count = min(vc.values)

# %%
count, index
# Out:
# (24153, [0, 1])

# %%
df_bal = pd.DataFrame()
for i in index:
  temp = df[df['Toxicity']==i].sample(count)
  df_bal = df_bal.append(temp, ignore_index = True)

# %%
df = df_bal.copy()

# %%
df['Toxicity'].value_counts()
# Out:
# 0    24153
# 1    24153
# Name: Toxicity, dtype: int64

# %%
from wordcloud import WordCloud
from wordcloud import ImageColorGenerator
from wordcloud import STOPWORDS
import matplotlib.pyplot as plt

# %%
# Toxic word cloud
wordcloud = WordCloud(stopwords=STOPWORDS, background_color="white").generate(" ".join(i for i in df[df['Toxicity']==1].tweet))
plt.figure( figsize=(15,10))
plt.imshow(wordcloud, interpolation='bilinear')
plt.axis("off")
plt.show()

# %%
# Non toxic word cloud
wordcloud = WordCloud(stopwords=STOPWORDS, background_color="white").generate(" ".join(i for i in df[df['Toxicity']==0].tweet))
plt.figure( figsize=(15,10))
plt.imshow(wordcloud, interpolation='bilinear')
plt.axis("off")
plt.show()

# %% [markdown]
# # Text Processing

# %%
# Import text processing libraries
import string
import nltk
from nltk.corpus import stopwords
# nltk.download('stopwords')

from nltk.stem.snowball import SnowballStemmer
snow_stemmer = SnowballStemmer(language='english')

from nltk.stem import PorterStemmer
from nltk.stem.wordnet import WordNetLemmatizer

import spacy
# !python -m spacy download en_core_web_sm
import en_core_web_sm

# %%
nlp = spacy.load('en_core_web_sm')

def clean_string(text, stem="None"):

    final_string = ""

    # Make lower
    text = text.lower()

    # Remove line breaks
    text = re.sub(r'\n', '', text)

    # Remove puncuation
    translator = str.maketrans('', '', string.punctuation)
    text = text.translate(translator)

    # Remove stop words
    text = text.split()
    useless_words = nltk.corpus.stopwords.words("english")
    useless_words = useless_words + ['hi', 'im', 'rt', 'u', 'user', 'n', 'youre', 'ð', '']

    text_filtered = [word for word in text if not word in useless_words]

    # Remove mentions
    text_filtered = [re.sub("@[A-Za-z0-9_]+","", w) for w in text_filtered]
    
    # Remove numbers
    text_filtered = [re.sub(r'\w*\d\w*', '', w) for w in text_filtered]
    text_filtered = [re.sub(r'[^a-zA-Z0-9]', '', w) for w in text_filtered]

    # Stem or Lemmatize
    if stem == 'Stem':
        stemmer = PorterStemmer() 
        text_stemmed = [stemmer.stem(y) for y in text_filtered]
    elif stem == 'Lem':
        lem = WordNetLemmatizer()
        text_stemmed = [lem.lemmatize(y) for y in text_filtered]
    elif stem == 'Spacy':
        text_filtered = nlp(' '.join(text_filtered))
        text_stemmed = [y.lemma_ for y in text_filtered]
    else:
        text_stemmed = text_filtered

    final_string = ' '.join(text_stemmed)

    return final_string

# %%
clean_string(''.join(df['tweet'].sample(1)), 'Lem')
# Out:
# 'brings best husband inlove'

# %%
df['tweet'] = df['tweet'].apply(lambda tweet: clean_string(tweet))

# %%
df.head()
# Out:
#    Unnamed: 0  Toxicity                                              tweet
# 0       22722         0  sign bunch free flowers using invitation code ...
# 1        4747         0  new squeegee amp frame screenprinting bolton s...
# 2       30691         0                          model love take time ur
# 3       13415         0  ooooohhhhh brand new brochure landing desk nea...
# 4       32706         0  nowplaying bt feat tori amos blue skies radio ...

# %%
# Toxic cleaned word cloud
wordcloud = WordCloud(stopwords=STOPWORDS, background_color="white").generate(" ".join(i for i in df[df['Toxicity']==1].tweet))
plt.figure( figsize=(15,10))
plt.imshow(wordcloud, interpolation='bilinear')
plt.axis("off")
plt.show()

# %%
# Non toxic word cloud
wordcloud = WordCloud(stopwords=STOPWORDS, background_color="white").generate(" ".join(i for i in df[df['Toxicity']==0].tweet))
plt.figure( figsize=(15,10))
plt.imshow(wordcloud, interpolation='bilinear')
plt.axis("off")
plt.show()

# %% [markdown]
# # Tokenization

# %%
text = df['tweet'].tolist()

# %%
tokenizer = Tokenizer()
tokenizer.fit_on_texts(text)

# %%
len(tokenizer.word_counts)
# Out:
# 53586

# %%
vocab_size = len(tokenizer.word_counts) + 1

# %%
encoded_text = tokenizer.texts_to_sequences(text)

# %%
max_length = 120
X = pad_sequences(encoded_text, maxlen=max_length, padding='post')

# %%
print(X)
# Out:
# [[ 1144   903   140 ...     0     0     0]
#  [   31 19079     8 ...     0     0     0]
#  [  172     4    40 ...     0     0     0]
#  ...
#  [53586  5670   411 ...     0     0     0]
#  [18275     1  1702 ...     0     0     0]
#  [  168   147   168 ...     0     0     0]]

# %%
X.shape
# Out:
# (48306, 120)

# %% [markdown]
# # Model Building

# %%
from keras.utils import np_utils
from tensorflow.keras.optimizers import Adam
from sklearn.svm import LinearSVC

# %%
y = df['Toxicity']
y
# Out:
# 0        0
# 1        0
# 2        0
# 3        0
# 4        0
#         ..
# 48301    1
# 48302    1
# 48303    1
# 48304    1
# 48305    1
# Name: Toxicity, Length: 48306, dtype: int64

# %%
x = df['tweet']
y = df['Toxicity']

# %%
print(y)
# Out:
# 0        0
# 1        0
# 2        0
# 3        0
# 4        0
#         ..
# 48301    1
# 48302    1
# 48303    1
# 48304    1
# 48305    1
# Name: Toxicity, Length: 48306, dtype: int64

# %%
x_train, x_test, y_train, y_test = train_test_split(X, y, test_size = 0.2, random_state=0, stratify=y)

# %%
x_train.shape, x_test.shape
# Out:
# ((38644, 120), (9662, 120))

# %%
from sklearn.naive_bayes import ComplementNB

# %%
# 65%
cnb = ComplementNB()
cnb.fit(x_train, y_train)
# Out:
# ComplementNB()

# %%
from sklearn.tree import DecisionTreeClassifier

# %%
# 88%
tree = DecisionTreeClassifier(criterion='entropy', splitter='best', class_weight='balanced', random_state=None)
tree.fit(x_train, y_train)

# %%
from sklearn.neural_network import MLPClassifier

# %%
# 54%
mlp = MLPClassifier()
mlp.fit(x_train, y_train)
# Out:
# MLPClassifier()

# %%
from sklearn.pipeline import Pipeline
from sklearn.svm import SVC
from sklearn.preprocessing import StandardScaler

# %%
# 73%
pipe = Pipeline([('scaler', StandardScaler()), ('svc', SVC())])
pipe.fit(x_train, y_train)
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-64-09436f939395> in <module>
#       1 # 73%
#       2 pipe = Pipeline([('scaler', StandardScaler()), ('svc', SVC())])
# ----> 3 pipe.fit(x_train, y_train)
#
# ~\anaconda3\lib\site-packages\sklearn\pipeline.py in fit(self, X, y, **fit_params)
#     344             if self._final_estimator != 'passthrough':
#     345                 fit_params_last_step = fit_params_steps[self.steps[-1][0]]
# --> 346                 self._final_estimator.fit(Xt, y, **fit_params_last_step)
#     347
#     348         return self
#
# ~\anaconda3\lib\site-packages\sklearn\svm\_base.py in fit(self, X, y, sample_weight)
#     224
#     225         seed = rnd.randint(np.iinfo('i').max)
# --> 226         fit(X, y, sample_weight, solver_type, kernel, random_seed=seed)
#     227         # see comment on the other call to np.iinfo in this file
#     228
#
# ~\anaconda3\lib\site-packages\sklearn\svm\_base.py in _dense_fit(self, X, y, sample_weight, solver_type, kernel, random_seed)
#     275         self.support_, self.support_vectors_, self._n_support, \
#     276             self.dual_coef_, self.intercept_, self._probA, \
# --> 277             self._probB, self.fit_status_ = libsvm.fit(
#     278                 X, y,
#     279                 svm_type=solver_type, sample_weight=sample_weight,
#
# KeyboardInterrupt:

# %%
from sklearn.svm import SVC

# %%
svc = SVC(kernel='linear')
svc.fit(x_train,y_train)

# %% [markdown]
# # Model Testing

# %%
from sklearn.metrics import classification_report, confusion_matrix
from mlxtend.plotting import plot_confusion_matrix

# %%
y_pred = svc.predict(x_test)

# %%
print(classification_report(y_test, y_pred))

# %%
plot_confusion_matrix(confusion_matrix(y_test, y_pred))

# %% [markdown]
# # Testing Custom Data

# %%
x = 'hello'

# %%
def get_encoded(x):
  x = clean_string(x)
  x = tokenizer.texts_to_sequences([x])
  x = pad_sequences(x, maxlen=max_length, padding = 'post')
  return x

# %%
pred = pipe.predict(get_encoded(x))

# %%
print(pred)
# Out:
# [1]
